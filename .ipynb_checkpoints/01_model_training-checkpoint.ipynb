# %%
import os
import pandas as pd

# 1. Securely set your Google Cloud credentials so pandas can authenticate
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "gcp-key.json"

# --- UPDATE THIS ---
project_id = "aero-optimize"
# -------------------

# 2. Write the SQL query to pull engineered features
query = f"""
    SELECT * FROM `{project_id}.flight_data.model_features`
"""

print("Fetching engineered features from BigQuery...")

# 3. Use pandas to run the query and load the data directly into a DataFrame
df = pd.read_gbq(query, project_id=project_id)

print(f"Success! Loaded {len(df)} rows into local memory.")

# 4. Display the first 5 rows to verify everything looks correct
display(df.head())
